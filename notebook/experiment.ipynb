# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
import pymongo
import certifi
ca = certifi.where()
mongo_url="mongodb+srv://Deepadmin:Root@cluster0.mhel9.mongodb.net/admin?authSource=admin&replicaSet=atlas-6qsgpk-shard-0&w=majority&readPreference=primary&appname=MongoDB%20Compass&retryWrites=true&ssl=true"

# %%
client=pymongo.MongoClient(mongo_url,tlsCAFile=ca)

# %%
database=client["ineuron"]
collection=database["sales"]

# %%
df=pd.DataFrame(list(collection.find()))

# %%
test_df=pd.read_csv("C:/Users/DEEPANSHU RAJPUT/Desktop/Projects/industry_ready_projects/store_sales_prediction/store_sales_prediction/artifact/01_30_2023_20_54_01/data_ingestion/ingested/test.csv")

train_df=pd.read_csv("C:/Users/DEEPANSHU RAJPUT/Desktop/Projects/industry_ready_projects/store_sales_prediction/store_sales_prediction/artifact/01_30_2023_20_54_01/data_ingestion/ingested/train.csv")

# %%
from scipy.stats import ks_2samp
is_same_dist=ks_2samp(train_df,test_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 from scipy.stats import ks_2samp
# ----> 2 is_same_dist=ks_2samp(train_df,test_df)
#
# File c:\Users\DEEPANSHU RAJPUT\Desktop\Projects\industry_ready_projects\store_sales_prediction\store_sales_prediction\venv\lib\site-packages\scipy\_lib\_util.py:700, in _rename_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     698         raise TypeError(message)
#     699     kwargs[new_name] = kwargs.pop(old_name)
# --> 700 return fun(*args, **kwargs)
#
# File c:\Users\DEEPANSHU RAJPUT\Desktop\Projects\industry_ready_projects\store_sales_prediction\store_sales_prediction\venv\lib\site-packages\scipy\stats\_stats_py.py:8108, in ks_2samp(data1, data2, alternative, method)
#    8106 if np.ma.is_masked(data2):
#    8107     data2 = data2.compressed()
# -> 8108 data1 = np.sort(data1)
# ...

# %%
train_df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDJ45       17.750          Low Fat         0.073397
# 1              FDQ57        7.275          Low Fat         0.027942
# 2              FDD29       12.150          Low Fat         0.018486
# 3              FDF50        4.905          Low Fat         0.117568
# 4              FDF10       15.500          Regular         0.000000
# ...              ...          ...              ...              ...
# 6813           DRM37       15.350          Low Fat         0.161350
# 6814           FDX21        7.050          Low Fat         0.085312
# 6815           NCY42        6.380          Low Fat         0.015186
# 6816           DRY23        9.395          Regular         0.109266
# 6817           FDL14        8.115              reg         0.053827
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0          Seafood   35.1216            OUT035                       2004
# ...
